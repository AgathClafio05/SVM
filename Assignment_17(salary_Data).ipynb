# %%
# SVM Classification
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-63737790-a3ef-458f-8488-4ab8be345e4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63737790-a3ef-458f-8488-4ab8be345e4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train=pd.read_csv('SalaryData_Train(1).csv')
train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2e6d0691-e73d-49c2-bd50-4c34fed0ebf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e6d0691-e73d-49c2-bd50-4c34fed0ebf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
test=pd.read_csv('SalaryData_Test(1).csv')
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
train[train.duplicated()].shape
# Out:
# (3258, 14)

# %%
train[train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
sl_t=train.drop_duplicates()

# %%
sl_t
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
sl_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26903 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            26903 non-null  int64
#  1   workclass      26903 non-null  object
#  2   education      26903 non-null  object
#  3   educationno    26903 non-null  int64
#  4   maritalstatus  26903 non-null  object
#  5   occupation     26903 non-null  object
#  6   relationship   26903 non-null  object
#  7   race           26903 non-null  object
#  8   sex            26903 non-null  object
#  9   capitalgain    26903 non-null  int64
#  10  capitalloss    26903 non-null  int64
#  11  hoursperweek   26903 non-null  int64
#  12  native         26903 non-null  object
#  13  Salary         26903 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.1+ MB

# %%
sl_t.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  26903.000000  26903.000000  26903.000000  26903.000000  26903.000000
# mean      39.049140     10.144296   1215.443259     98.427499     41.164591
# std       13.188825      2.620154   7805.366384    425.493211     12.347051
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       29.000000      9.000000      0.000000      0.000000     40.000000
# 50%       38.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
sl_t.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
test[test.duplicated].shape
# Out:
# (930, 14)

# %%
test[test.duplicated]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
sl_test=test.drop_duplicates()

# %%
sl_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sl_test[sl_test.duplicated()].shape
# Out:
# (0, 14)

# %%
sl_t['Salary'].value_counts()
# Out:
#  <=50K    20023
#  >50K      6880
# Name: Salary, dtype: int64

# %%
sl_test['Salary'].value_counts()
# Out:
#  <=50K    10620
#  >50K      3510
# Name: Salary, dtype: int64

# %%
pd.crosstab(sl_t['occupation'],sl_t['Salary'])
# Out:
# Salary               <=50K   >50K
# occupation
#  Adm-clerical         2816    475
#  Armed-Forces            8      1
#  Craft-repair         2472    757
#  Exec-managerial      1903   1743
#  Farming-fishing       843    114
#  Handlers-cleaners    1081     78
#  Machine-op-inspct    1442    223
#  Other-service        2782    132
#  Priv-house-serv       140      1
#  Prof-specialty       2085   1698
#  Protective-serv       424    202
#  Sales                2315    890
#  Tech-support          594    264
#  Transport-moving     1118    302

# %%
pd.crosstab(sl_test['occupation'],sl_test['Salary'])
# Out:
# Salary               <=50K   >50K
# occupation
#  Adm-clerical         1451    252
#  Armed-Forces            2      3
#  Craft-repair         1338    391
#  Exec-managerial      1022    875
#  Farming-fishing       427     57
#  Handlers-cleaners     597     51
#  Machine-op-inspct     801    112
#  Other-service        1449     64
#  Priv-house-serv        87      2
#  Prof-specialty       1043    856
#  Protective-serv       231     95
#  Sales                1248    467
#  Tech-support          369    130
#  Transport-moving      555    155

# %% [markdown]
# #visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize']=(12,6)
sns.heatmap(sl_t.isna(), cmap =('viridis'), yticklabels=False)
# Out:
# <Axes: >

# %%
plt.rcParams['figure.figsize']=(12,6)
sns.heatmap(sl_test.isna(), cmap =('viridis'), yticklabels=False)
# Out:
# <Axes: >

# %%
# let's plot pair plot to visualise the attributes all at once
sns.pairplot(data=sl_t, hue = 'Salary')

# %%
# let's plot pair plot to visualise the attributes all at once
sns.pairplot(data=sl_test, hue = 'Salary')

# %%
pd.crosstab(sl_t['Salary'],sl_t['sex']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
pd.crosstab(sl_test['Salary'],sl_test['sex']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
pd.crosstab(sl_t['Salary'],sl_t['relationship']).mean().plot(kind='bar')
# Out:
# <Axes: xlabel='relationship'>

# %%
string_columns = ["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings(action='ignore')

# %%
#Preprocessing the data. As, there are categorical variables
number = LabelEncoder()
for i in string_columns:
        sl_t[i]= number.fit_transform(sl_t[i])
        sl_test[i]=number.fit_transform(sl_test[i])

# %%
sl_t
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
sl_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
#Capturing the column names which can help in futher process
colnames = sl_t.columns
colnames
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
x_train = sl_t[colnames[0:13]]
y_train = sl_t[colnames[13]]

# %%
x_test = sl_test[colnames[0:13]]
y_test = sl_test[colnames[13]]

# %%
y_test
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 14130, dtype: object

# %%
#Normalmization
from sklearn import preprocessing

# %%
x_train = preprocessing.normalize(x_train)
print(x_train)
# Out:
# [[1.79301817e-02 2.29874124e-03 4.13773424e-03 ... 0.00000000e+00
#   1.83899299e-02 1.70106852e-02]
#  [7.59496105e-01 6.07596884e-02 1.36709299e-01 ... 0.00000000e+00
#   1.97468987e-01 5.62027118e-01]
#  [5.56541382e-01 2.92916517e-02 1.61104084e-01 ... 0.00000000e+00
#   5.85833034e-01 5.41895556e-01]
#  ...
#  [4.30802311e-01 3.19112823e-02 1.11689488e-01 ... 0.00000000e+00
#   6.06314364e-01 5.90358723e-01]
#  [7.13552349e-01 2.46052534e-02 1.35328894e-01 ... 0.00000000e+00
#   4.92105068e-01 4.55197188e-01]
#  [3.46108334e-03 1.99677885e-04 7.32152244e-04 ... 0.00000000e+00
#   2.66237180e-03 2.46269391e-03]]

# %%
x_test = preprocessing.normalize(x_test)
print(x_test)
# Out:
# [[4.10222105e-01 3.28177684e-02 1.64088842e-02 ... 0.00000000e+00
#   6.56355368e-01 6.07128716e-01]
#  [5.09803107e-01 2.68317425e-02 1.47574584e-01 ... 0.00000000e+00
#   6.70793562e-01 4.96387236e-01]
#  [4.39003072e-01 1.56786811e-02 1.09750768e-01 ... 0.00000000e+00
#   6.27147246e-01 5.80111202e-01]
#  ...
#  [5.04696587e-01 2.65629783e-02 1.19533402e-01 ... 0.00000000e+00
#   6.64074457e-01 4.91415098e-01]
#  [8.06529390e-03 3.66604268e-04 1.64971921e-03 ... 0.00000000e+00
#   7.33208536e-03 6.78217896e-03]
#  [4.34690384e-01 3.72591758e-02 1.11777527e-01 ... 0.00000000e+00
#   7.45183516e-01 4.59529835e-01]]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((26903, 13), (26903,), (14130, 13), (14130,))

# %% [markdown]
# #svm model

# %%
# clf = SVC()
# param_grid = [{'kernel':['linear','rbf'],'gamma':[0.5,0.1,0.01],'C':[10,0.1,0.001,0.0001] }]
# gsv = RandomizedSearchCV(clf,param_grid,cv=10,verbose=300)
# gsv.fit(x_train,y_train)

# %%
# gsv.best_params_ , gsv.best_score_

# %%
clf = SVC(kernel='rbf',C=0.1)
clf.fit(x_train , y_train)
y_pred = clf.predict(x_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 77.37438075017693
# array([[9798,  822],
#        [2375, 1135]])

# %%
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype=object)

# %%
clf = SVC(kernel='linear',C=0.01)
clf.fit(x_train , y_train)
y_pred = clf.predict(x_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 77.3177636234961
# array([[10148,   472],
#        [ 2733,   777]])

# %%
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype=object)

# %%
#'sigmoid'
model_sig = SVC(kernel = "sigmoid")
model_sig.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
pred_test_sig = model_sig.predict(x_test)

# %%
np.mean(pred_test_sig==y_test)
# Out:
# 0.6380750176928521
